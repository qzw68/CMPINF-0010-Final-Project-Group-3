# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import geopandas
# %matplotlib inline

# %%
# Read data from WPRDC
povertyData = pd.read_csv("https://data.wprdc.org/dataset/c6265ffb-c86e-4a2c-870b-1aaa0772c449/resource/7996d143-c155-466e-8414-115f74997dd7/download/poverty-status-of-individuals-in-the-past-12-months-by-living-arrangement.csv")
#Simplify the dataset
poverty = povertyData[["Neighborhood","Estimate; Total:","Estimate; Income in the past 12 months below poverty level:"]]

poverty.columns = ["Neighborhood", "Population","Income below poverty level:"]


#Filter out the neighborhood that has less than 300 people
poverty=poverty[poverty['Population']>300]

#Calculate the poverty rate
poverty["Poverty rate"] = poverty["Income below poverty level:"]/poverty["Population"]
poverty.sort_values(by="Poverty rate").head(10)
# Out:
#       Neighborhood  Population  Income below poverty level:  Poverty rate
# 82  Swisshelm Park      1286.0                         51.0      0.039658
# 55   New Homestead       933.0                         42.0      0.045016
# 80  Strip District       689.0                         33.0      0.047896
# 5       Banksville      3944.0                        252.0      0.063895
# 66   Regent Square      1009.0                         67.0      0.066402
# 81     Summer Hill      1168.0                         81.0      0.069349
# 63    Point Breeze      5333.0                        442.0      0.082880
# 45   Lincoln Place      3465.0                        293.0      0.084560
# 90         Windgap      1617.0                        147.0      0.090909
# 36      Greenfield      7465.0                        682.0      0.091360

# %%
# Visualize the proverty rate
plt.figure(figsize=(25,10))
plt.xticks(rotation=90,size=15)
plt.title("Barblot Poverty Rate", size=22)
plt.xlabel("Neighborhood",size=22)
plt.ylabel("Poverty Rate",size=22)

g=sns.barplot(x="Neighborhood", y = 'Poverty rate', data = poverty.sort_index(), palette="Spectral")

# %%
poverty = poverty.sort_values(by='Poverty rate')
poverty["Score"] = range(100,100-len(poverty),-1)
poverty.head(30)
# Out:
#              Neighborhood  Population  Income below poverty level:  \
# 82         Swisshelm Park      1286.0                         51.0
# 55          New Homestead       933.0                         42.0
# 80         Strip District       689.0                         33.0
# 5              Banksville      3944.0                        252.0
# 66          Regent Square      1009.0                         67.0
# 81            Summer Hill      1168.0                         81.0
# 63           Point Breeze      5333.0                        442.0
# 45          Lincoln Place      3465.0                        293.0
# 90                Windgap      1617.0                        147.0
# 36             Greenfield      7465.0                        682.0
# 13              Brookline     13191.0                       1361.0
# 51            Morningside      3326.0                        349.0
# 65            Polish Hill      1453.0                        161.0
# 26          East Carnegie       525.0                         59.0
# 60              Overbrook      3659.0                        458.0
# 39          Highland Park      6900.0                        889.0
# 12       Brighton Heights      7249.0                        945.0
# 1          Allegheny West       331.0                         45.0
# 76    Squirrel Hill North      8281.0                       1138.0
# 84              Troy Hill      2401.0                        332.0
# 74          Spring Garden       777.0                        108.0
# 64     Point Breeze North      1763.0                        254.0
# 20         Chartiers City       414.0                         62.0
# 77    Squirrel Hill South     14915.0                       2242.0
# 17  Central Lawrenceville      4356.0                        664.0
# 89               Westwood      3550.0                        558.0
# 24       Duquesne Heights      2555.0                        405.0
# 61            Perry North      4062.0                        645.0
# 79        Stanton Heights      5010.0                        835.0
# 11                Bon Air       832.0                        140.0
#
#     Poverty rate  Score
# 82      0.039658    100
# 55      0.045016     99
# 80      0.047896     98
# 5       0.063895     97
# 66      0.066402     96
# 81      0.069349     95
# 63      0.082880     94
# 45      0.084560     93
# 90      0.090909     92
# 36      0.091360     91
# 13      0.103176     90
# 51      0.104931     89
# 65      0.110805     88
# 26      0.112381     87
# 60      0.125171     86
# 39      0.128841     85
# 12      0.130363     84
# 1       0.135952     83
# 76      0.137423     82
# 84      0.138276     81
# 74      0.138996     80
# 64      0.144073     79
# 20      0.149758     78
# 77      0.150318     77
# 17      0.152433     76
# 89      0.157183     75
# 24      0.158513     74
# 61      0.158789     73
# 79      0.166667     72
# 11      0.168269     71

# %%
# Poverty Rate Scores visualized by a chloropleth map
neighborhoods = geopandas.read_file("Neighborhoods/Neighborhoods_.shp")
poverty_map = neighborhoods.merge(poverty, how='left', left_on='hood', right_on='Neighborhood')
poverty_map.plot(column = "Score",
               cmap = 'GnBu',
               edgecolor="white",
               legend=True,
               legend_kwds={'label': "Score"}, 
               figsize=(12, 8))

# %%
# dataframe to be used for final notebook
povertyRanking = poverty[["Neighborhood","Score"]]
povertyRanking
# Out:
#          Neighborhood  Score
# 82     Swisshelm Park    100
# 55      New Homestead     99
# 80     Strip District     98
# 5          Banksville     97
# 66      Regent Square     96
# ..                ...    ...
# 83    Terrace Village     20
# 19    Central Oakland     19
# 6   Bedford Dwellings     18
# 4   Arlington Heights     17
# 58  Northview Heights     16
#
# [85 rows x 2 columns]
